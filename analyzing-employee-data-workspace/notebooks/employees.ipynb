# %%
# %pip install matplotlib
# Out:
# ...
#      |████████████████████████████████| 7.4 MB 3.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 98 kB 3.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 244 kB 3.7 MB/s eta 0:00:01
# ...
#   Using cached packaging-23.0-py3-none-any.whl (42 kB)
# ...
#      |████████████████████████████████| 65 kB 2.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.3 MB 100 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 965 kB 3.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 19.8 MB 3.4 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/Users/robsontrajano/Documents/GitHub/hands_on_data_science/analyzing-employee-data-workspace/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pandas
# Out:
# ...
#      |████████████████████████████████| 12.0 MB 1.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 499 kB 3.7 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/Users/robsontrajano/Documents/GitHub/hands_on_data_science/analyzing-employee-data-workspace/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install seaborn
# Out:
# ...
#      |████████████████████████████████| 293 kB 2.0 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/Users/robsontrajano/Documents/GitHub/hands_on_data_science/analyzing-employee-data-workspace/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

sns.set_style('darkgrid')

# %%
df = pd.read_csv('../files/employees.csv')

# %%
df.head()
# Out:
#    EmployeeKey  ParentEmployeeKey  EmployeeNationalIDAlternateKey  \
# 0            1               18.0                        14417807
# 1            2                7.0                       253022876
# 2            3               14.0                       509647174
# 3            4                3.0                       112457891
# 4            5                3.0                       112457891
#
#    ParentEmployeeNationalIDAlternateKey  SalesTerritoryKey FirstName  \
# 0                                   NaN                 11       Guy
# 1                                   NaN                 11     Kevin
# 2                                   NaN                 11   Roberto
# 3                                   NaN                 11       Rob
# 4                                   NaN                 11       Rob
#
#      LastName MiddleName  NameStyle                         Title  ...  \
# 0     Gilbert          R          0  Production Technician - WC60  ...
# ...

# %%
df.isna().sum()
# Out:
# EmployeeKey                               0
# ParentEmployeeKey                         1
# EmployeeNationalIDAlternateKey            0
# ParentEmployeeNationalIDAlternateKey    296
# SalesTerritoryKey                         0
# FirstName                                 0
# LastName                                  0
# MiddleName                               13
# NameStyle                                 0
# Title                                     0
# HireDate                                  0
# BirthDate                                 0
# LoginID                                   0
# EmailAddress                              0
# Phone                                     0
# MaritalStatus                             0
# EmergencyContactName                      0
# EmergencyContactPhone                     0
# SalariedFlag                              0
# Gender                                    0
# PayFrequency                              0
# ...

# %%
df.columns
# Out:
# Index(['EmployeeKey', 'ParentEmployeeKey', 'EmployeeNationalIDAlternateKey',
#        'ParentEmployeeNationalIDAlternateKey', 'SalesTerritoryKey',
#        'FirstName', 'LastName', 'MiddleName', 'NameStyle', 'Title', 'HireDate',
#        'BirthDate', 'LoginID', 'EmailAddress', 'Phone', 'MaritalStatus',
#        'EmergencyContactName', 'EmergencyContactPhone', 'SalariedFlag',
#        'Gender', 'PayFrequency', 'BaseRate', 'VacationHours', 'SickLeaveHours',
#        'CurrentFlag', 'SalesPersonFlag', 'DepartmentName', 'StartDate',
#        'EndDate', 'Status'],
#       dtype='object')

# %%
df.drop(['ParentEmployeeKey', 'EmployeeNationalIDAlternateKey', 'ParentEmployeeNationalIDAlternateKey'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    EmployeeKey  SalesTerritoryKey FirstName    LastName MiddleName  NameStyle  \
# 0            1                 11       Guy     Gilbert          R          0
# 1            2                 11     Kevin       Brown          F          0
# 2            3                 11   Roberto  Tamburello        NaN          0
# 3            4                 11       Rob     Walters        NaN          0
# 4            5                 11       Rob     Walters        NaN          0
#
#                           Title   HireDate   BirthDate  \
# 0  Production Technician - WC60  1/28/2006  11/12/1981
# 1           Marketing Assistant  8/26/2006   12/1/1986
# 2           Engineering Manager  6/11/2007   6/12/1974
# 3          Senior Tool Designer   7/5/2007   7/23/1974
# 4          Senior Tool Designer   7/5/2007   7/23/1974
#
#                     LoginID  ... PayFrequency BaseRate VacationHours  \
# 0      adventure-works\guy1  ...            1  12.4500            21
# ...

# %%
# export csv file
df.to_csv('../files/employees_clean.csv', index=False)
